# %%
import requests 
from bs4 import BeautifulSoup

# %%
url1 = "https://aws.amazon.com/ar/what-is/artificial-intelligence/"

# %%
response1 = requests.get(url1)

# %%
soup1 = BeautifulSoup(response1.content , 'html.parser')

# %%
arabic_text = [soup1.find('p').text.strip()]

# %%
arabic_text
# Out:
# ['الذكاء الاصطناعي والذي يُعرف اختصارًا بـ AI هو تقنية ذات قدرات حل تشبه قدرات الإنسان في حل المشكلات. يبدو أن الذكاء الاصطناعي في العمل يحاكي الذكاء البشري - يمكنه التعرف على الصور وكتابة القصائد وإجراء تنبؤات قائمة على البيانات.']

# %%
url2 = "https://www.aljazeera.net/tech/2016/5/4/%D8%A7%D9%84%D8%B0%D9%83%D8%A7%D8%A1-%D8%A7%D9%84%D8%A7%D8%B5%D8%B7%D9%86%D8%A7%D8%B9%D9%8A-%D9%85%D8%A7-%D9%87%D9%88-%D9%88%D9%85%D8%A7-%D8%A3%D8%A8%D8%B1%D8%B2-%D9%85%D8%B8%D8%A7%D9%87%D8%B1%D9%87"

# %%
response2 = requests.get(url2)

# %%
soup2 = BeautifulSoup(response2.content , "html.parser")

# %%
arabic_text.append(soup2.find('p' , style='text-align:right').text.strip())

# %%
arabic_text
# Out:
# ['الذكاء الاصطناعي والذي يُعرف اختصارًا بـ AI هو تقنية ذات قدرات حل تشبه قدرات الإنسان في حل المشكلات. يبدو أن الذكاء الاصطناعي في العمل يحاكي الذكاء البشري - يمكنه التعرف على الصور وكتابة القصائد وإجراء تنبؤات قائمة على البيانات.',
#  'يعرف الذكاء الاصطناعي بأنه الذكاء الذي تبديه الآلات والبرامج بما يحاكي القدرات الذهنية البشرية وأنماط عملها، مثل القدرة على التعلم والاستنتاج ورد الفعل على أوضاع لم تبرمج في الآلة، كما أنه اسم لحقل أكاديمي يعنى بكيفية صنع حواسيب وبرامج قادرة على اتخاذ\xa0سلوك ذكي.']

# %%
url3 = "https://www.aljazeera.net/encyclopedia/2016/6/6/%D8%A7%D9%84%D8%B0%D9%83%D8%A7%D8%A1-%D8%A7%D9%84%D8%A7%D8%B5%D8%B7%D9%86%D8%A7%D8%B9%D9%8A-%D8%AD%D9%8A%D9%86%D9%85%D8%A7-%D8%AA%D9%81%D9%83%D8%B1-%D8%A7%D9%84%D8%A2%D9%84%D8%A9"

response3 = requests.get(url3)

soup3 = BeautifulSoup(response3.content , 'html.parser')
arabic_text.append(soup3.find('p').text.strip())

# %%
url = "https://mawdoo3.com/%D8%AA%D8%B9%D8%B1%D9%8A%D9%81_%D8%A7%D9%84%D8%B0%D9%83%D8%A7%D8%A1_%D8%A7%D9%84%D8%A7%D8%B5%D8%B7%D9%86%D8%A7%D8%B9%D9%8A"

response = requests.get(url)
soup = BeautifulSoup(response.content, 'html.parser')
texts = soup.find_all('p')

arabic_texts = [p.text for p in texts if any('\u0600' <= c <= '\u06FF' for c in p.text)]

# %%
for i, text in enumerate(arabic_texts):
    print(f"Text {i}:\n{text}\n")
# Out:
# Text 0:
# تمت الكتابة بواسطة: ناهد عبادة
#
#
# Text 1:
#  تم التدقيق بواسطة:
#                                                 وسام درويش
#
# Text 2:
#
# آخر تحديث: ٠٦:٢٠ ، ٢ ديسمبر ٢٠٢١
#
# Text 3:
# يرتبط مفهوم الذكاء الاصطناعي (بالإنجليزية: Artificial Intelligence) بالذكاء المرتبط بالأجهزة الرقمية أو الإلكترونية مثل؛ الكمبيوتر، الأجهزة الخلوية أو الروبوتات، ويعبر الذكاء الاصطناعي عن قدرة هذه الأجهزة الرقمية على أداء المهمات المرتبطة بالكائنات الذكية.[١]
#
# Text 4:
# ينطبق مصطلح الذكاء الاصطناعي على الأنظمة التي تتمتع بالعمليات الفكرية للإنسان مثل؛ القدرة على التفكير، واكتشاف المعنى والتعلم من التجارب السابقة.[١]
#
# Text 5:
# ومن الأمثلة على العمليات التي تؤديها الأجهزة الرقمية والتي تعود لوجود الذكاء الاصطناعي؛ اكتشاف البراهين للنظريات الرياضية، ولعب الشطرنج، والتشخيص الطبي، ومحركات البحث على الشبكة، والتعرف على الصوت أو خط اليد.[١]
#
# Text 6:
# يعود تاريخ الذكاء الاصطناعي إلى الفلاسفة الكلاسيكيين في اليونان، وبدأت دراسة موضوع وجود الذكاء الاصطناعي في عام 1940 م في مدرسة فكرية تسمى الاتصالية، بحيث بدأت دراسة عملية التفكير فيها، وقدّم آلان تورينج ورقة بحثية يدرس فيها آلة للتفكير تقلد الإنسان دون وجود اختلافات ملحوظة فيها في عام 1950 م.[٢]
#
# Text 7:
# جاء هودجكين هكسلي بعده ليقدم نموذج يحاكي دماغ الإنسان على شكل شبكة كهربائية تمثل الخلايا العصبية، وتيار كهربائي يحاكي النبضات التي تشغل أو توقف الخلايا، وساعدت هذه النماذج والدراسات على إطلاق مفهوم الذكاء الاصطناعي عام 1956م في مؤتمر أقامته كلية دارتموث.[٢]
#
# Text 8:
# نظرًا لعدم توفر السرعات والسعات التخزينية العالية توقفت أبحاث الذكاء الاصطناعي لفترة طويلة، ثم استؤنفت في الثمانينات بعد تقديم الولايات المتحدة الأمريكية وبريطانيا مشروع الجيل الخامس في تكنولوجيا الكمبيوتر.[٢]
#
# Text 9:
# في بداية التسعينات حولت أبحاث الذكاء الاصطناعي مجالها إلى ما يسمى بالوكيل الذكي، والذي يستخدم في خدمات استرداد الأخبار، والتسوق عبر الإنترنت وتصفح الويب، ولا يزال الباحثون يحاولون استخدام الذكاء الاصطناعي في مجالات غير مسبوقة مثل؛ المساعدات المادية التي تقدمها الروبوتات، وبرامج خدمة العملاء، والرد على الهاتف وغيرها.[٢]
#
# Text 10:
# يعمل الذكاء الاصطناعي في البيئة الرقمية من خلال توفر الأجهزة الرقمية والبرامج المتخصصة لتحليل وتصميم خوارزميات، والتعلم الآلي، وبشكل عام فإنّ نظام الذكاء الاصطناعي يستوعب كميات كبيرة من البيانات التدريبية.[٣]
#
# Text 11:
# تستخدم البيانات التدريبية في تكوين الارتباطات والأنماط التي تستخدم فيما بعد في بناء التنبؤات المستقبلية، مثل الرد الآلي في الروبوتات الذكية، وعملية تحديد الكائنات في الصور ووصفها من خلال مراجعة ملايين الأمثلة المحفوظة لدى الجهاز الذكي.[٣]
#
# Text 12:
# يدخل الذكاء الاصطناعي في العديد من المجالات الإلكترونية والرقمية، وهو موجود على أشكال مختلفة وفي أجهزة كثيرة، بحيث يحاكي الذكاء الموجود في العقل البشري، ويندرج الذكاء الاصطناعي تحت فئتين رئيسيتين، وهما كالآتي:
#
#
# Text 13:
# يعرف الذكاء الاصطناعي الضيق أيضًا باسم الذكاء الاصطناعي الضعيف، وهو نوع من أنواع الذكاء التي تحاكي الذكاء البشري ولكنه يختص بنوع واحد ومحدود من الذكاء، ويركز الذكاء الاصطناعي الضيق على أداء نوع واحد من المهمات ولكن بشكل جيد جدًا، بحيث يركز على تنفيذ مهمة واحدة باحترافية، ولكنه يعمل في ظل قيود أكثر بكثير من الذكاء البشري.[٤]
#
# Text 14:
# ومن الأمثلة على الذكاء الاصطناعي الضيق:[٤]
#
#
# Text 15:
# يعرف الذكاء الاصطناعي العام أيضًا باسم الذكاء الاصطناعي القوي، وهو نوع من أنواع الذكاء الموجود في الآلات والأجهزة الذكية، ويمتاز الذكاء الاصطناعي العام بأنه نوع من الذكاء الموجود في الآلة والتي يكسبها ذكاءً عامًا مثل الإنسان، بحيث يستخدم هذا الذكاء في حل أي مشكلة.[٤]
#
# Text 16:
# ومن أمثلة الأجهزة التي تتمتع بالذكاء الاصطناعي العام؛ الروبوتات التي تستخدم لإنجاز مهام عديدة والتي تتخذ قراراتها بناءً على الموقف، ولكن بناء الروبوتات التي تتمتع بذكاء شبيه بالموجود لدى الإنسان لا زال أمرًا صعبًا وبحاجة لبناء شبكات عصبية كبيرة ومعقدة كالموجودة في الدماغ.[٤]
#
# Text 17:
# فيما يأتي أنواع الذكاء الاصطناعي:
#
#
# Text 18:
# تعرف الآلات التفاعلية بأنها أبسط مستوى موجود للروبوت، إذ إنّها آلة مصممة للتعامل مع نوع واحد من البيانات والرد على المواقف الحالية فقط،[٥] وهي آلات غير قادرة على إنشاء الذكريات أو استخدام المعلومات الحالية لبناء واتخاذ القرارات المستقبلية للتحسين من مستواها أو تطوير ذكائها، وهي فقط مصممة للرد على الموقف الحالي.[٦]
#
# Text 19:
# من أمثلة الآلات التفاعلية؛ الآلات المصممة للعب الشطرنج ضد الإنسان مثل (Deep Blue) من (IBM)، حيث إنّ هذه الآلة مصممة للرد على حركات اللاعب من خلال تقييم القطع على رقعة الشطرنج وتحريكها وفقًا لاستراتيجيات اللعب المشفرة لديها.[٥]
#
# Text 20:
# تعد آلة الذاكرة المحدودة آلة قادرة على تخزين عدد محدود من المعلومات المبنية على البيانات التي تعاملت معها آلة الذاكرة المحدودة سابقًا، بحيث يمكن لآلة الذاكرة المحدودة بناء المعرفة عن طريق الذاكرة وذلك عند اقترانها مع البيانات المبرمجة مسبقًا لديها.[٥]
#
# Text 21:
# من أمثلة الآلات التي تستخدم الذاكرة المحدودة؛ السيارات ذاتية القيادة، بحيث تخزن هذه السيارات البيانات المبرمجة مسبقًا مثل؛ الخرائط أو العلامات المرورية، ومقارنة هذه البيانات المخزنة مع المعلومات المحيطة بالسيارة مثل؛ سرعة واتجاهات السيارات القريبة وحركة المشاة جنبًا إلى جنب واتخاذ الإجراء المناسب بناءً على هذه البيانات.[٥]
#
# Text 22:
# استخدمت نظرية العقل في تصميم الروبوت الشهير صوفيا، وهو روبوت قادر على استخدام المعلومات في التفاعل مع المواقف بطريقة تشبه الإنسان، والتي من شأنها تعليم الآلة أو الروبوت كيفية التصرف في موقف مختلف وجديد.[٥]
#
# Text 23:
# تستند نظرية العقل في تطوير وتصميم الروبوتات التي تستخدم كروبوتات محادثة إلى العقل البشري الذي يستند إلى المشاعر والأفكار الموجودة لدى الإنسان قبل أن يقوم بعملية اتخاذ القرار، بحيث يقوم روبوت نظرية العقل صوفيا بالتحدث إلى البشر، واستخدام المعلومات والصور في اتخاذ القرار والرد على البشر، بالإضافة إلى إظهار تعبيرات وجهية مبهرة.[٥]
#
# Text 24:
# تعد أجهزة الوعي الذاتي هدفًا نهائيًا لوجود الذكاء الاصطناعي، وهي أجهزة غير موجودة حاليًا، فهذه الآلات لديها وعي بمستوى الإنسان العقلي وتفهم سبب وجودها في هذا العالم، بحيث لا تطلب الآلة شيئًا تحتاجه فحسب، وإنما تفهم أنها بحاجة إلى شيء ما، وهذا يعني أن الآلة تفهم حالتها الداخلية بعمق وتستطيع التنبؤ بمشاعر الآخرين من حولها تمامًا كالبشر.[٥]
#
# Text 25:
# على سبيل المثال عندما يصرخ شخص أمامنا فإننا ندرك أنه غاضب، وهذا الاستنتاج مبني على المشاعر التي يشعرها الشخص نفسه، بحيث تعود هذه الاستنتاجات إلى وجود العقل.[٥]
#
# Text 26:
# إن لكل شيء فوائد، ولكن غالبًا ما يقابلها عيوب ومضار، وفيما يأتي توضيح لمزايا وعيوب الذكاء الاصطناعي:[٧]
#
# Text 27:
# يستخدم الذكاء الاصطناعي في العديد من التطبيقات التكنولوجية والحياتية المهمة، والتي سهلت الكثير من مناحي الحياة وقامت بأداء وظائف مختلفة كانت مقتصرة على العقل البشري وحده،[٨] ومن أهم تطبيقات الذكاء الاصطناعي ما يأتي:[٩]
#
# Text 28:
# والتي تستخدم في العديد من الصناعات مثل الرعاية الصحية، والتمويل، والتسويق.
#
#
# Text 29:
# مثل الآلات المرسلة إلى الفضاء؛ الأقمار الصناعية، وبناء الخرائط، وتكنولوجيا تتبع المواقع.
#
#
# Text 30:
# مثل الروبوتات التي تستخدم في عمليات الرد على دردشات الزبائن، والروبوتات التي تقوم بوظائف خدمة العملاء والتسويق الإلكتروني.
#
#
# Text 31:
# مثل الخوارزميات التي تستخدم في تحليل الأسهم في السوق المالية، وتحليل الأرباح والخسائر والتنبؤ بها.
#
#
# Text 32:
# بحيث تعرض الإعلانات التي تهم الشخص المستهدف من خلال تحليل بياناته وفهم توجهاته من عمليات بحثه على الإنترنت.
#
#
# Text 33:
# بحيث تتمكن آلات الرعاية الصحية من تحليل حالة المريض بناءً على بياناته، والتنبؤ بالأمراض التي يمكن أن تحدث له في المستقبل، وتحديد نوع العلاج.
#
#
# Text 34:
# تستخدم هذه التقنية في العديد من الأجهزة مثل الهاتف الذكي، وتعمل على تعلم وإدراك الأنماط للخروج بنتائج سريعة وفعالة.
#
#
# Text 35:
# بحيث تساعد وتقلد الذكاء البشري من خلال التواصل الصوتي.
#
#
# Text 36:
# من الأمثلة على تطبيقات اللياقة البدنية التي تستخدم الذكاء الاصطناعي، الساعات الذكية التي تعد الخطوات، وحساب السعرات الحرارية، وغيرها من التطبيقات التي تهتم باللياقة البدنية.
#
#
# Text 37:
#
#                                         تم الإرسال بنجاح، شكراً لك!
#
#
# Text 38:
# جميع الحقوق محفوظة ©
#                                 موضوع 2025
#
# Text 39:
# جميع الحقوق محفوظة ©
#                                 موضوع 2025

# %%
arabic_Text = arabic_text + arabic_texts

# %%
len(arabic_Text)
# Out:
# 43

# %%
scores = []
for text in texts:
    print("\nText:", text)
    score = float(input("Assign a relevance score (0–10): "))
    scores.append(score)

# %%
scores
# Out:
# [7.0,
#  8.0,
#  9.0,
#  8.0,
#  8.0,
#  8.0,
#  7.0,
#  7.0,
#  6.0,
#  9.0,
#  5.0,
#  7.0,
#  7.0,
#  5.0,
#  5.0,
#  8.0,
#  5.0,
#  4.0,
#  4.0,
#  6.0,
#  6.0,
#  7.0,
#  8.0,
#  3.0,
#  3.0,
#  5.0]

# %%
import pandas as pd

df = pd.DataFrame({
    'Text': arabic_Text,
    'Score': scores
})

# %%
df.to_csv('arabic_text_dataset.csv', index=False)

# %%
import pandas a
df.read_csv('arabic_text_dataset.csv')

# %%
import pandas as pd
import re
import nltk
from nltk.corpus import stopwords
from nltk.stem.isri import ISRIStemmer
from pyarabic.araby import strip_tashkeel, strip_tatweel, normalize_hamza

# %%
# Download required NLTK resources
nltk.download('punkt')
nltk.download('stopwords')
# This is needed for Arabic tokenization nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /home/salah/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to /home/salah/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt_tab to /home/salah/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# True

# %%
# Load Arabic stopwords
arabic_stopwords = set(stopwords.words("arabic"))
stemmer = ISRIStemmer()

# %%
def preprocess_arabic(text):
    # Add error handling to handle NaN values or non-string data
    if pd.isna(text) or not isinstance(text, str):
        return ""
        
    # Remove diacritics and elongation
    text = strip_tashkeel(text)
    text = strip_tatweel(text)
    
    # Normalize Hamza and alef variations
    text = normalize_hamza(text)
    text = re.sub(r'[^\u0600-\u06FF\s]', '', text)  # Keep only Arabic characters
    
    # Tokenize - use a more reliable method for Arabic
    try:
        words = nltk.word_tokenize(text, language='arabic')
    except LookupError:
        # Fallback to simple whitespace tokenization if NLTK tokenization fails
        words = text.split()
    
    # Remove stopwords and short words
    filtered = [stemmer.stem(w) for w in words if w not in arabic_stopwords and len(w) > 2]
    
    return ' '.join(filtered)

# %%
# processing my dataframe
try:
    df['Cleaned_Text'] = df['Text'].apply(preprocess_arabic)
    print(df[['Text', 'Cleaned_Text']].head())
except Exception as e:
    print(f"Error processing dataframe: {e}")
# Out:
#                                                 Text  \
# 0  الذكاء الاصطناعي والذي يُعرف اختصارًا بـ AI هو...
# 1  يعرف الذكاء الاصطناعي بأنه الذكاء الذي تبديه ا...
# 2  الذكاء الاصطناعي تعبير يطلق على القدرات التي ت...
# 3  يرتبط مفهوم الذكاء الاصطناعي (بالإنجليزية: Art...
# 4  ينطبق مصطلح الذكاء الاصطناعي على الأنظمة التي ...
#
#                                         Cleaned_Text
# 0  ذكء صطناع عرف خصر قني قدر تشب قدر ءنس شكل بدو ...
# 1  عرف ذكء صطناع بءن ذكء بده ءءل رمج يحك قدر ذهن ...
# 2  ذكء صطناع عبر طلق قدر تبد ءءل رامج، يحك قدر ذه...
# 3  ربط فهم ذكء صطناع ءنجليزية ذكء ربط ءجهز رقم ءل...
# 4  طبق صطلح ذكء صطناع ءنظم متع عمل فكر ءنس ثل؛ قد...

# %%
df.head()
# Out:
#                                                 Text  Score  \
# 0  الذكاء الاصطناعي والذي يُعرف اختصارًا بـ AI هو...    7.0
# 1  يعرف الذكاء الاصطناعي بأنه الذكاء الذي تبديه ا...    8.0
# 2  الذكاء الاصطناعي تعبير يطلق على القدرات التي ت...    9.0
# 3  يرتبط مفهوم الذكاء الاصطناعي (بالإنجليزية: Art...    8.0
# 4  ينطبق مصطلح الذكاء الاصطناعي على الأنظمة التي ...    8.0
#
#                                         Cleaned_Text
# 0  ذكء صطناع عرف خصر قني قدر تشب قدر ءنس شكل بدو ...
# 1  عرف ذكء صطناع بءن ذكء بده ءءل رمج يحك قدر ذهن ...
# 2  ذكء صطناع عبر طلق قدر تبد ءءل رامج، يحك قدر ذه...
# 3  ربط فهم ذكء صطناع ءنجليزية ذكء ربط ءجهز رقم ءل...
# 4  طبق صطلح ذكء صطناع ءنظم متع عمل فكر ءنس ثل؛ قد...

# %%
import torch
from torch.utils.data import DataLoader, Dataset
from torch.nn.utils.rnn import pad_sequence
from torch import nn
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
# Out:
# 2025-05-05 14:32:44.544299: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-05-05 14:32:44.553603: I external/local_xla/xla/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2025-05-05 14:32:44.577280: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1746451964.615292   53335 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1746451964.626817   53335 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1746451964.654772   53335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746451964.654801   53335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746451964.654805   53335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1746451964.654808   53335 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-05-05 14:32:44.664175: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# Parameters for preprocessing
MAX_NB_WORDS = 20000
MAX_SEQUENCE_LENGTH = 200

# Tokenize the text and pad sequences
tokenizer = Tokenizer(num_words=MAX_NB_WORDS)
tokenizer.fit_on_texts(df['Cleaned_Text'])
X = tokenizer.texts_to_sequences(df['Cleaned_Text'])
X_pad = pad_sequences(X, maxlen=MAX_SEQUENCE_LENGTH)

# Convert labels to tensor
y = torch.tensor(df['Score'].values, dtype=torch.float32)  # For regression, use float; for classification, use long

# Convert text sequences into tensors
X_tensor = torch.tensor(X_pad, dtype=torch.long)

# %%
class TextDataset(Dataset):
    def __init__(self, texts, labels):
        self.texts = texts
        self.labels = labels

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        return self.texts[idx], self.labels[idx]

# Create DataLoader for batching
dataset = TextDataset(X_tensor, y)
train_loader = DataLoader(dataset, batch_size=64, shuffle=True)

# %%
class RNNModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(RNNModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.rnn = nn.RNN(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)  # Regression output (for classification, use `softmax` and multiple units)
        
    def forward(self, x):
        x = self.embedding(x)
        out, _ = self.rnn(x)
        out = out[:, -1, :]  # Get the output of the last time step
        out = self.fc(out)
        return out

# %%
class GRUModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(GRUModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.gru = nn.GRU(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)  # Regression output (for classification, use `softmax` and multiple units)

    def forward(self, x):
        x = self.embedding(x)
        out, _ = self.gru(x)
        out = out[:, -1, :]  # Get the output of the last time step
        out = self.fc(out)
        return out

# %%
class LSTMModel(nn.Module):
    def __init__(self, vocab_size, embedding_dim, hidden_dim):
        super(LSTMModel, self).__init__()
        self.embedding = nn.Embedding(vocab_size, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim, hidden_dim, batch_first=True)
        self.fc = nn.Linear(hidden_dim, 1)  # Regression output (for classification, use `softmax` and multiple units)

    def forward(self, x):
        x = self.embedding(x)
        out, _ = self.lstm(x)
        out = out[:, -1, :]  # Get the output of the last time step
        out = self.fc(out)
        return out

# %%
def train_model(model, train_loader, num_epochs=5, lr=0.001):
    criterion = nn.MSELoss()  # For regression; use `nn.CrossEntropyLoss()` for classification
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)

    for epoch in range(num_epochs):
        model.train()  # Set the model to training mode
        total_loss = 0
        for texts, labels in train_loader:
            optimizer.zero_grad()
            output = model(texts)
            loss = criterion(output.squeeze(), labels)  # Remove extra dimensions
            loss.backward()
            optimizer.step()
            total_loss += loss.item()

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss / len(train_loader)}")

# Choose a model and train it
rnn_model = RNNModel(vocab_size=MAX_NB_WORDS, embedding_dim=128, hidden_dim=128)
train_model(rnn_model, train_loader)
# Out:
# /home/salah/miniconda3/lib/python3.12/site-packages/torch/autograd/graph.py:825: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 803: system has unsupported display driver / cuda driver combination (Triggered internally at /opt/conda/conda-bld/pytorch_1729647329220/work/c10/cuda/CUDAFunctions.cpp:108.)
#   return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
# Epoch 1/5, Loss: 42.712345123291016
# Epoch 2/5, Loss: 40.31608200073242
# Epoch 3/5, Loss: 37.9826774597168
# Epoch 4/5, Loss: 35.674049377441406
# Epoch 5/5, Loss: 33.35989761352539

# %%
import torch
from torch.utils.data import Dataset, DataLoader
import random
from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F

# Larger sample of Arabic text (still synthetic, but larger and more diverse)
sample_texts = [
    "أنا أحب تعلم البرمجة لأنها ممتعة وتساعدني في تطوير مهاراتي",
    "الذكاء الاصطناعي يعد من أهم المجالات التقنية في العصر الحالي",
    "تعلم الآلة يساعد الشركات على اتخاذ قرارات أفضل وتحليل البيانات",
    "إن البرمجة هي أداة قوية لتحقيق أهداف كبيرة في التكنولوجيا",
    "أنا أدرس الذكاء الاصطناعي في الجامعة وأتعلم العديد من المفاهيم الجديدة",
    "البرمجة تتطلب التفكير التحليلي والصبر، وهي مهارة يمكن تطويرها مع الممارسة",
    "المستقبل سيكون مشرقًا مع تطور الذكاء الاصطناعي وتحسينات التكنولوجيا",
    "العالم الرقمي يتطور بسرعة، وأصبح الذكاء الاصطناعي جزءًا من حياتنا اليومية",
    "تعلم البرمجة يفتح الأبواب للعديد من الفرص المهنية في جميع أنحاء العالم",
    "الذكاء الاصطناعي سيغير وجه العالم في المستقبل القريب، مما سيؤثر على كل الصناعات"
]

# Sample relevance scores (between 0 and 10)
sample_scores = [random.uniform(0, 10) for _ in range(len(sample_texts))]

# Tokenization and word-to-index conversion (simplified example)
word_to_index = {
    "أنا": 1, "أحب": 2, "تعلم": 3, "البرمجة": 4, "لأنها": 5, "ممتعة": 6, "وتساعدني": 7,
    "في": 8, "تطوير": 9, "مهاراتي": 10, "الذكاء": 11, "الاصطناعي": 12, "يعد": 13, "من": 14,
    "أهم": 15, "المجالات": 16, "التقنية": 17, "في": 18, "العصر": 19, "الحالي": 20, "الآلة": 21,
    "يساعد": 22, "الشركات": 23, "على": 24, "اتخاذ": 25, "قرارات": 26, "أفضل": 27, "وتحليل": 28,
    "البيانات": 29, "إن": 30, "هي": 31, "أداة": 32, "قوية": 33, "لتحقيق": 34, "أهداف": 35,
    "كبيرة": 36, "التكنولوجيا": 37, "أدرس": 38, "في": 39, "الجامعة": 40, "وأتعلم": 41, "العديد": 42,
    "من": 43, "المفاهيم": 44, "الجديدة": 45, "التحليلي": 46, "والصبر": 47, "هي": 48, "يمكن": 49,
    "تطويرها": 50, "الممارسة": 51, "المستقبل": 52, "سيكون": 53, "مشرقًا": 54, "مع": 55, "تحسينات": 56,
    "الرقمي": 57, "يتطور": 58, "سرعة": 59, "وأصبح": 60, "جزءًا": 61, "من": 62, "حياتنا": 63,
    "اليومية": 64, "يفتح": 65, "الأبواب": 66, "للتعلم": 67, "المهنية": 68, "العالم": 69, "سيغير": 70,
    "وجه": 71, "العديد": 72, "الصناعات": 73
}

# Function to convert text to token indices (for simplicity, just mapping known words)
def tokenize(text):
    return [word_to_index.get(word, 0) for word in text.split()]

# Create a custom dataset
class TextDataset(Dataset):
    def __init__(self, texts, scores, word_to_index, max_length=15):
        self.texts = texts
        self.scores = scores
        self.word_to_index = word_to_index
        self.max_length = max_length
        
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = self.texts[idx]
        score = self.scores[idx]
        tokenized_text = torch.tensor(tokenize(text))
        
        # Pad sequences to a fixed length
        if len(tokenized_text) < self.max_length:
            padding = torch.zeros(self.max_length - len(tokenized_text), dtype=torch.long)
            tokenized_text = torch.cat([tokenized_text, padding])
        elif len(tokenized_text) > self.max_length:
            tokenized_text = tokenized_text[:self.max_length]
        
        return tokenized_text, torch.tensor(score, dtype=torch.float)

# Create the test dataset and DataLoader
test_dataset = TextDataset(sample_texts, sample_scores, word_to_index, max_length=15)
test_loader = DataLoader(test_dataset, batch_size=2, shuffle=False)

# Check a batch from the DataLoader
for batch in test_loader:
    inputs, labels = batch
    print("Tokenized Text:", inputs)
    print("Labels (Scores):", labels)
# Out:
# Tokenized Text: tensor([[ 1,  2,  3,  4,  5,  6,  7, 39,  9, 10,  0,  0,  0,  0,  0],
#         [11, 12, 13, 62, 15, 16, 17, 39, 19, 20,  0,  0,  0,  0,  0]])
# Labels (Scores): tensor([8.7893, 5.6103])
# Tokenized Text: tensor([[ 3, 21, 22, 23, 24, 25, 26, 27, 28, 29,  0,  0,  0,  0,  0],
#         [30,  4, 48, 32, 33, 34, 35, 36, 39, 37,  0,  0,  0,  0,  0]])
# Labels (Scores): tensor([1.1971, 1.7436])
# Tokenized Text: tensor([[ 1, 38, 11, 12, 39, 40, 41, 72, 62, 44, 45,  0,  0,  0,  0],
#         [ 4,  0,  0, 46,  0,  0,  0, 49, 50, 55, 51,  0,  0,  0,  0]])
# Labels (Scores): tensor([3.4469, 9.6124])
# Tokenized Text: tensor([[52, 53, 54, 55,  0, 11, 12,  0, 37,  0,  0,  0,  0,  0,  0],
#         [69, 57, 58,  0, 60, 11, 12, 61, 62, 63, 64,  0,  0,  0,  0]])
# Labels (Scores): tensor([1.9792, 4.2000])
# Tokenized Text: tensor([[ 3,  4, 65, 66,  0, 62,  0, 68, 39,  0,  0, 69,  0,  0,  0],
#         [11, 12, 70, 71, 69, 39, 52,  0,  0,  0, 24,  0, 73,  0,  0]])
# Labels (Scores): tensor([0.4784, 6.3379])

# %%
def evaluate_model(model, test_loader):
    model.eval()  # Set the model to evaluation mode
    total_loss = 0
    with torch.no_grad():
        for texts, labels in test_loader:
            output = model(texts)
            loss = nn.MSELoss()(output.squeeze(), labels)
            total_loss += loss.item()

    print(f"Evaluation Loss: {total_loss / len(test_loader)}")

    

# You can also use a test set like this:
evaluate_model(rnn_model, test_loader)
# Out:
# Evaluation Loss: 23.292538857460023
